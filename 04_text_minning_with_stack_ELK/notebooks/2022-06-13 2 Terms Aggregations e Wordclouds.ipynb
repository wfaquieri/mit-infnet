# %% [markdown]
# # Criação de Mapping e Inserção em Bulk

# %%
import json
import wordcloud
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15080/4249196814.py in <module>
#       1 import json
# ----> 2 import wordcloud
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
import matplotlib.pyplot as plt

# %%
import elasticsearch

ES_URL = 'https://localhost:9200'
ES_USER = 'elastic'
ES_PASS = 'elastic123'

client = elasticsearch.Elasticsearch(
    ES_URL,
    basic_auth=(ES_USER, ES_PASS),
    verify_certs=False
)
# Out:
# /home/felipefg/.pyenv/versions/3.9.1/envs/infnet/lib/python3.9/site-packages/elasticsearch/_sync/client/__init__.py:395: SecurityWarning: Connecting to 'https://localhost:9200' using TLS with verify_certs=False is insecure
#   _transport = transport_class(

# %%
# Desligando warning para facilitar nossa vida
import urllib3
urllib3.disable_warnings()

# %%
INDEX_NAME = '20newsgroup_teste_insercao'

# %%
client.info()
# Out:
# ObjectApiResponse({'name': '5503825f1474', 'cluster_name': 'docker-cluster', 'cluster_uuid': 'GxIrgAZwSzuIel58XNDppg', 'version': {'number': '8.2.2', 'build_flavor': 'default', 'build_type': 'docker', 'build_hash': '9876968ef3c745186b94fdabd4483e01499224ef', 'build_date': '2022-05-25T15:47:06.259735307Z', 'build_snapshot': False, 'lucene_version': '9.1.0', 'minimum_wire_compatibility_version': '7.17.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'You Know, for Search'})

# %% [markdown]
# # Terms Aggregation sobre campo Keyword

# %%
QUERY = {
    'match_all': {}
}

AGG = {
    'grupos': {
        'terms': {
            'field': 'newsgroup.raw',
            'size': 20,
        }
    }
}

# %%
resp = client.search(index=INDEX_NAME, query=QUERY, aggregations=AGG, size=0)

# %%
resp['hits']
# Out:
# {'total': {'value': 10000, 'relation': 'gte'}, 'max_score': None, 'hits': []}

# %%
resp['aggregations']
# Out:
# {'grupos': {'doc_count_error_upper_bound': 0,
#   'sum_other_doc_count': 0,
#   'buckets': [{'key': 'rec.sport.hockey', 'doc_count': 600},
#    {'key': 'soc.religion.christian', 'doc_count': 599},
#    {'key': 'rec.motorcycles', 'doc_count': 598},
#    {'key': 'rec.sport.baseball', 'doc_count': 597},
#    {'key': 'sci.crypt', 'doc_count': 595},
#    {'key': 'rec.autos', 'doc_count': 594},
#    {'key': 'sci.med', 'doc_count': 594},
#    {'key': 'comp.windows.x', 'doc_count': 593},
#    {'key': 'sci.space', 'doc_count': 593},
#    {'key': 'comp.os.ms-windows.misc', 'doc_count': 591},
#    {'key': 'sci.electronics', 'doc_count': 591},
#    {'key': 'comp.sys.ibm.pc.hardware', 'doc_count': 590},
#    {'key': 'misc.forsale', 'doc_count': 585},
#    {'key': 'comp.graphics', 'doc_count': 584},
#    {'key': 'comp.sys.mac.hardware', 'doc_count': 578},
#    {'key': 'talk.politics.mideast', 'doc_count': 564},
#    {'key': 'talk.politics.guns', 'doc_count': 546},
#    {'key': 'alt.atheism', 'doc_count': 480},
#    {'key': 'talk.politics.misc', 'doc_count': 465},
#    {'key': 'talk.religion.misc', 'doc_count': 377}]}}

# %%
df_newsgroup_agg = pd.DataFrame(resp['aggregations']['grupos']['buckets'])

# %%
df_newsgroup_agg
# Out:
#                          key  doc_count
# 0           rec.sport.hockey        600
# 1     soc.religion.christian        599
# 2            rec.motorcycles        598
# 3         rec.sport.baseball        597
# 4                  sci.crypt        595
# 5                  rec.autos        594
# 6                    sci.med        594
# 7             comp.windows.x        593
# 8                  sci.space        593
# 9    comp.os.ms-windows.misc        591
# 10           sci.electronics        591
# 11  comp.sys.ibm.pc.hardware        590
# 12              misc.forsale        585
# 13             comp.graphics        584
# 14     comp.sys.mac.hardware        578
# 15     talk.politics.mideast        564
# 16        talk.politics.guns        546
# 17               alt.atheism        480
# 18        talk.politics.misc        465
# 19        talk.religion.misc        377

# %%
df_newsgroup_agg.plot(x='key', kind='bar')
# Out:
# <AxesSubplot:xlabel='key'>

# %% [markdown]
# # Wordcloud sobre campo analizado

# %%
QUERY = {
    'match_all': {}
}

AGG = {
    'mensagem': {
        'terms': {
            'field': 'message',
            'size': 100,
        }
    }
}

# %%
resp = client.search(index=INDEX_NAME, query=QUERY, aggregations=AGG, size=0)

# %%
frequencies = {}

buckets = resp['aggregations']['mensagem']['buckets']

for bucket in buckets:
    frequencies[bucket['key']] = bucket['doc_count']

# %%
cloud = wordcloud.WordCloud(background_color='white')
cloud.generate_from_frequencies(frequencies)

fig, ax = plt.subplots(figsize=(16, 6))
ax.imshow(cloud)

# %% [markdown]
# # Wordcloud para grupo rec.sport.hockey

# %%
QUERY = {
    'term': {
        'newsgroup.raw': 'rec.sport.hockey'
    }
}

AGG = {
    'mensagem': {
        'terms': {
            'field': 'message',
            'size': 100,
        }
    }
}

resp = client.search(index=INDEX_NAME, query=QUERY, aggregations=AGG, size=0)

frequencies = {}

buckets = resp['aggregations']['mensagem']['buckets']

for bucket in buckets:
    frequencies[bucket['key']] = bucket['doc_count']

cloud = wordcloud.WordCloud(background_color='white')
cloud.generate_from_frequencies(frequencies)

fig, ax = plt.subplots(figsize=(16, 6))
ax.imshow(cloud)

# %% [markdown]
# # Wordcloud e Grupos que casem com o termo 'windows'

# %%
#QUERY = {
#    'term': {
#        'newsgroup.raw': 'sci.electronics'
#    }
#}

QUERY = {
    'term': {
        'message': 'windows'
    }
}

AGG = {
    'mensagem': {
        'terms': {
            'field': 'message',
            'size': 100,
            'exclude': '(windows)',
        }
    },
    'grupos': {
        'terms': {
            'field': 'newsgroup.raw',
            'size': 20,
        }
    }
}

resp = client.search(index=INDEX_NAME, query=QUERY, aggregations=AGG, size=0)

frequencies = {}

buckets = resp['aggregations']['mensagem']['buckets']

for bucket in buckets:
    frequencies[bucket['key']] = bucket['doc_count']

cloud = wordcloud.WordCloud(background_color='white')
cloud.generate_from_frequencies(frequencies)

fig, ax = plt.subplots(figsize=(16, 6))
ax.imshow(cloud)

# %%
resp['aggregations']['grupos']
# Out:
# {'doc_count_error_upper_bound': 0,
#  'sum_other_doc_count': 0,
#  'buckets': [{'key': 'comp.os.ms-windows.misc', 'doc_count': 401},
#   {'key': 'comp.sys.ibm.pc.hardware', 'doc_count': 94},
#   {'key': 'comp.windows.x', 'doc_count': 94},
#   {'key': 'comp.graphics', 'doc_count': 64},
#   {'key': 'misc.forsale', 'doc_count': 43},
#   {'key': 'rec.autos', 'doc_count': 16},
#   {'key': 'comp.sys.mac.hardware', 'doc_count': 13},
#   {'key': 'sci.crypt', 'doc_count': 10},
#   {'key': 'talk.politics.misc', 'doc_count': 6},
#   {'key': 'talk.politics.guns', 'doc_count': 5},
#   {'key': 'talk.politics.mideast', 'doc_count': 5},
#   {'key': 'rec.motorcycles', 'doc_count': 4},
#   {'key': 'sci.electronics', 'doc_count': 4},
#   {'key': 'sci.med', 'doc_count': 4},
#   {'key': 'sci.space', 'doc_count': 2},
#   {'key': 'rec.sport.hockey', 'doc_count': 1}]}
